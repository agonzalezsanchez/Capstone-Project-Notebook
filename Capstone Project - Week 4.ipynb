# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ### Introduction

# %% [markdown]
# The purpose of this project is to help people explore better services and amenities around their neighborhood.  It will aid people who are looking for better neighborhoods to live in, such as discovering schools, supermarkets, hospitals, parks, recreational spaces, shopping malls, theatres, cafes, and other places of interest. The project will help decide which neighborhood in South Florida is the optimal choice to move to.

# %% [markdown]
# The state of Florida has seen an increase of migration due to lower taxes, great weather, job opportunities, etc.  This project aims to create a comparative analysis of features between neighborhoods. The features include median housing price, average salary, school ratings, crime rates, emergency management resources, water resources, waste management, recreational activities, transportation, and hospital ratings.

# %% [markdown]
# ### The Problem to Solve

# %% [markdown]
# The objective of this project is to recommend the optimal neighborhood in a new city for people who are moving there.
# 1.	Sorted list of houses in terms of prices from ascending or descending
# 2.	Sorted list of schools in terms of ratings, location, and reviews

# %% [markdown]
# ### Four Square API and Work Flow

# %% [markdown]
# This project would use Four-square API as its prime data gathering source as it has a database of millions of places, especially their places API which provides the ability to perform location search, location sharing and details about a business.
#
# Using credentials of Foursquare API features of near-by places of the neighborhoods would be mined. Due to http request limitations the number of places per neighborhood parameter would reasonably be set to 100 and the radius parameter would be set to 500.

# %% [markdown]
# ### Clustering Approach

# %% [markdown]
# To compare the similarities of two cities, we decided to explore neighborhoods, segment them, and group them into clusters to find similar neighborhoods in a big city like Miami and Tampa. To be able to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm

# %% [markdown]
# ### Libraries needed

# %% [markdown]
# Pandas: to create and manipulate data frames
#
# Folium: to visualize neighborhoods cluster distribution using interactive leaflet map
#
# JSON: to handle JSON files
#
# Scikit Learn: to import k-means clustering
#
# XML: to separate data from presentation, data is stored in plain text format
#
# Matplotlib:  Python plotting module
#
# Geocoder:  to retrieve location/geospatial data
#
# Beautiful soup and Requests: to scrap and handle http requests.
